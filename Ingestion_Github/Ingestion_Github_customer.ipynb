# %%
pip install pandas

# %%
import pandas

# %% [markdown]
# ##Libraries-> Module -> Functions

# %%
df = pandas.read_csv("https://raw.githubusercontent.com/Bhevendra/ML-Datasets/refs/heads/main/retail_data/customers.csv")

# %%
df

# %% [markdown]
# - Import
# - Session Creation
# - Dataframe Creation
#   - Dataframe
#   - Data Write
# - Delta Format
#   - Mode

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()
df = spark.createDataFrame(df)
df.write.format("delta").mode("overwrite").saveAsTable("batch_1.data.customers")

# %%
df.display()
